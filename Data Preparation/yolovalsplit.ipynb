# %%
import os
import shutil

def move_files_by_type(source_folder, image_dest_folder, text_dest_folder):

    # --- Configuration: Define your file extensions ---
    image_extensions = ('.jpg', '.jpeg', '.png')
    text_extensions = ('.txt','.xml')

    # --- 1. Create destination folders if they don't exist ---
    # The exist_ok=True argument prevents an error if the directory already exists.
    os.makedirs(image_dest_folder, exist_ok=True)
    print(f"Ensured image destination folder exists: {image_dest_folder}")

    os.makedirs(text_dest_folder, exist_ok=True)
    print(f"Ensured text destination folder exists: {text_dest_folder}")

    # --- 2. Check if source folder exists ---
    if not os.path.isdir(source_folder):
        print(f"Error: Source folder '{source_folder}' not found.")
        return

    # --- 3. Iterate through files in the source folder ---
    moved_image_count = 0
    moved_text_count = 0
    skipped_count = 0

    print(f"\nScanning files in: {source_folder}...")
    for filename in os.listdir(source_folder):
        source_file_path = os.path.join(source_folder, filename)

        # Ensure it's a file and not a directory
        if os.path.isfile(source_file_path):
            # Get the file extension (and convert to lowercase for case-insensitive comparison)
            _, file_extension = os.path.splitext(filename)
            file_extension_lower = file_extension.lower()

            try:
                if file_extension_lower in image_extensions:
                    destination_file_path = os.path.join(image_dest_folder, filename)
                    shutil.move(source_file_path, destination_file_path)
                    print(f"Moved image: {filename} -> {image_dest_folder}")
                    moved_image_count += 1
                elif file_extension_lower in text_extensions:
                    destination_file_path = os.path.join(text_dest_folder, filename)
                    shutil.move(source_file_path, destination_file_path)
                    print(f"Moved text: {filename} -> {text_dest_folder}")
                    moved_text_count += 1
                else:
                    print(f"Skipped (unknown type): {filename}")
                    skipped_count += 1
            except Exception as e:
                print(f"Error moving file {filename}: {e}")
                skipped_count += 1
        else:
            print(f"Skipped (is a directory): {filename}")
            # If you also want to process subdirectories, you'd need recursive logic here.

    print("\n--- Summary ---")
    print(f"Moved {moved_image_count} image file(s).")
    print(f"Moved {moved_text_count} text file(s).")
    print(f"Skipped {skipped_count} item(s).")
    print("File organization complete.")

# --- How to use the function ---
if __name__ == "__main__":
    # --- !!! IMPORTANT: Define your folder paths here !!! ---
    # You can use absolute paths (e.g., "C:/Users/YourUser/Downloads/SourceFiles")
    # or relative paths (e.g., "my_files_to_sort")
    # Relative paths are relative to where you run the Python script.

    # Example:
    # Create these folders in the same directory as your script for testing:
    # - source_files/ (put some .jpg, .png, .txt, .md files here)
    # - destination_images/
    # - destination_texts/

    source_directory = r"C:\MTP1\augmented\Dataset\test"  # CHANGE THIS
    images_destination = r"C:\MTP1\augmented\Dataset\images\test"  # CHANGE THIS
    texts_destination = r"C:\MTP1\augmented\Dataset\labels\test"   # CHANGE THIS

    # Create dummy source folder and files for easy testing if they don't exist
    if not os.path.exists(source_directory):
        os.makedirs(source_directory)
        print(f"Created dummy source directory: {source_directory}")
        # Create some dummy files
        open(os.path.join(source_directory, "image1.jpg"), 'w').close()
        open(os.path.join(source_directory, "photo.PNG"), 'w').close()
        open(os.path.join(source_directory, "document.txt"), 'w').close()
        open(os.path.join(source_directory, "notes.MD"), 'w').close()
        open(os.path.join(source_directory, "archive.zip"), 'w').close() # This will be skipped
        print("Created dummy files in source directory for testing.")


    # Call the function
    move_files_by_type(source_directory, images_destination, texts_destination)
# Out:
# Ensured image destination folder exists: C:\MTP1\augmented\Dataset\images\test
# Ensured text destination folder exists: C:\MTP1\augmented\Dataset\labels\test
#
# Scanning files in: C:\MTP1\augmented\Dataset\test...
# Moved image: duck (1)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (1)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (1)_13.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (1)_13.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (1)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (1)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (1)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (1)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (11)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (11)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (12)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (12)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (12)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (12)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (13)_1.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (13)_1.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (13)_13.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (13)_13.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (13)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (13)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (14)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (14)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (14)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (14)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (16)_13.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (16)_13.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (16)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (16)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (17)_1.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (17)_1.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (17)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (17)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (17)_7.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (17)_7.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (19)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (19)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (19)_15.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (19)_15.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (19)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (19)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (19)_8.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (19)_8.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (2)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (2)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (2)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (2)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (20)_12.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (20)_12.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (20)_13.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (20)_13.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (20)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (20)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (22)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (22)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (22)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (22)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (23)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (23)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (23)_2.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (23)_2.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (23)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (23)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (24)_12.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (24)_12.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (24)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (24)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (25)_1.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (25)_1.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (25)_2.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (25)_2.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (25)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (25)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (26)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (26)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (27)_1.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (27)_1.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (27)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (27)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (27)_2.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (27)_2.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (28)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (28)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (28)_2.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (28)_2.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (29)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (29)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (3)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (3)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (3)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (3)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (30)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (30)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (30)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (30)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (31)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (31)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (31)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (31)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (32)_1.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (32)_1.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (33)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (33)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (33)_13.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (33)_13.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (34)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (34)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (35)_1.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (35)_1.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (35)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (35)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (35)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (35)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (35)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (35)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (36)_2.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (36)_2.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (36)_7.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (36)_7.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (36)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (36)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (4)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (4)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (41)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (41)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (42)_2.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (42)_2.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (42)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (42)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (43)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (43)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (43)_8.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (43)_8.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (44)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (44)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (44)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (44)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (44)_7.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (44)_7.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (44)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (44)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (45)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (45)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (46)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (46)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (46)_13.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (46)_13.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (46)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (46)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (47)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (47)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (47)_13.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (47)_13.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (47)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (47)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (47)_8.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (47)_8.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (49)_1.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (49)_1.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (49)_15.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (49)_15.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (49)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (49)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (50)_13.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (50)_13.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (50)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (50)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (50)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (50)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (51)_1.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (51)_1.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (51)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (51)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (52)_12.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (52)_12.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (52)_15.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (52)_15.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (52)_2.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (52)_2.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (52)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (52)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (53)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (53)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (53)_8.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (53)_8.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (54)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (54)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (54)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (54)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (55)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (55)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (55)_7.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (55)_7.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (56)_15.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (56)_15.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (56)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (56)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (58)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (58)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (59)_12.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (59)_12.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (59)_13.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (59)_13.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (59)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (59)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (59)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (59)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (59)_8.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (59)_8.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (6)_13.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (6)_13.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (6)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (6)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (6)_8.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (6)_8.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (60)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (60)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (60)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (60)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (61)_13.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (61)_13.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (61)_7.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (61)_7.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (61)_8.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (61)_8.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (61)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (61)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (62)_1.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (62)_1.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (62)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (62)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (62)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (62)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (62)_2.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (62)_2.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (63)_15.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (63)_15.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (63)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (63)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (63)_8.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (63)_8.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (63)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (63)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (64)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (64)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (64)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (64)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (65)_15.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (65)_15.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (65)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (65)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (66)_2.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (66)_2.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (68)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (68)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (68)_12.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (68)_12.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (68)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (68)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (68)_2.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (68)_2.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (68)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (68)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (68)_8.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (68)_8.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (69)_12.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (69)_12.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (69)_15.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (69)_15.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (69)_8.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (69)_8.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (7)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (7)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (7)_15.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (7)_15.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (7)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (7)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (7)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (7)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (7)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (7)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (7)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (7)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (70)_15.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (70)_15.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (70)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (70)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (71)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (71)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (71)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (71)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (71)_8.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (71)_8.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (72)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (72)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (73)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (73)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (73)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (73)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (73)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (73)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (74)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (74)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (74)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (74)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (77)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (77)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (77)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (77)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (78)_1.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (78)_1.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (78)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (78)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (78)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (78)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (78)_7.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (78)_7.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (78)_8.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (78)_8.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (79)_1.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (79)_1.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (79)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (79)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (79)_13.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (79)_13.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (79)_7.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (79)_7.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (8)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (8)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (80)_12.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (80)_12.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (82)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (82)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (82)_7.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (82)_7.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (83)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (83)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (84)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (84)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (84)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (84)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (84)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (84)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (85)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (85)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (85)_7.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (85)_7.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (86)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (86)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (87)_15.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (87)_15.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (88)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (88)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (88)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (88)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (88)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (88)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (89)_12.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (89)_12.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (9)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (9)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (90)_12.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (90)_12.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (90)_2.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (90)_2.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (90)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (90)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (92)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (92)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (92)_2.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (92)_2.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (93)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (93)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (93)_13.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (93)_13.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (94)_1.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (94)_1.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (94)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (94)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (94)_15.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (94)_15.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (94)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (94)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (94)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (94)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (96)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (96)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (96)_12.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (96)_12.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (96)_2.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (96)_2.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (97)_13.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (97)_13.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (97)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (97)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (97)_8.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (97)_8.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (98)_15.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (98)_15.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (98)_2.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (98)_2.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck (99)_12.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck (99)_12.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (1)_1.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (1)_1.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (10)_1.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (10)_1.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (10)_15.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (10)_15.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (10)_2.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (10)_2.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (10)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (10)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (11)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (11)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (13)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (13)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (15)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (15)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (15)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (15)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (16)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (16)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (16)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (16)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (17)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (17)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (18)_1.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (18)_1.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (19)_15.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (19)_15.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (19)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (19)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (19)_8.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (19)_8.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (2)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (2)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (2)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (2)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (2)_7.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (2)_7.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (20)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (20)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (3)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (3)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (4)_15.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (4)_15.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (4)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (4)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (5)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (5)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (5)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (5)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (6)_1.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (6)_1.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (6)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (6)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (6)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (6)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (7)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (7)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (7)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (7)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (7)_8.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (7)_8.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (8)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (8)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (8)_13.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (8)_13.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (8)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (8)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (8)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (8)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (8)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (8)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (8)_8.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (8)_8.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (9)_8.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (9)_8.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: duck1 (9)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: duck1 (9)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (1)_8.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (1)_8.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (1)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (1)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (10)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (10)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (10)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (10)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (10)_15.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (10)_15.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (10)_2.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (10)_2.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (10)_8.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (10)_8.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (100)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (100)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (100)_7.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (100)_7.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (100)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (100)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (102)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (102)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (102)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (102)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (103)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (103)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (104)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (104)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (104)_13.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (104)_13.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (104)_15.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (104)_15.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (104)_2.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (104)_2.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (104)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (104)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (105)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (105)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (106)_2.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (106)_2.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (106)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (106)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (107)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (107)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (107)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (107)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (108)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (108)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (108)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (108)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (108)_8.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (108)_8.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (109)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (109)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (109)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (109)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (109)_8.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (109)_8.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (11)_2.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (11)_2.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (11)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (11)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (11)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (11)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (110)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (110)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (110)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (110)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (111)_1.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (111)_1.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (111)_7.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (111)_7.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (112)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (112)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (112)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (112)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (113)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (113)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (113)_12.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (113)_12.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (113)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (113)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (113)_7.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (113)_7.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (114)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (114)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (114)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (114)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (114)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (114)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (114)_8.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (114)_8.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (115)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (115)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (116)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (116)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (117)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (117)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (117)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (117)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (118)_1.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (118)_1.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (118)_15.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (118)_15.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (118)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (118)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (118)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (118)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (119)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (119)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (119)_12.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (119)_12.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (119)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (119)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (120)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (120)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (120)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (120)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (120)_2.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (120)_2.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (120)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (120)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (121)_12.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (121)_12.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (121)_2.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (121)_2.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (121)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (121)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (121)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (121)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (121)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (121)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (121)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (121)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (122)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (122)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (122)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (122)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (122)_2.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (122)_2.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (122)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (122)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (122)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (122)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (123)_13.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (123)_13.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (123)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (123)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (123)_7.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (123)_7.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (125)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (125)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (125)_15.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (125)_15.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (126)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (126)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (126)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (126)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (126)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (126)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (127)_15.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (127)_15.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (127)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (127)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (127)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (127)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (127)_8.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (127)_8.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (128)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (128)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (129)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (129)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (13)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (13)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (130)_1.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (130)_1.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (130)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (130)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (130)_12.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (130)_12.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (130)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (130)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (130)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (130)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (130)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (130)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (131)_1.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (131)_1.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (131)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (131)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (133)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (133)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (134)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (134)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (135)_1.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (135)_1.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (138)_7.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (138)_7.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (139)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: fish (139)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: fish (139)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# ...
# Moved image: poppy (45)_13.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (45)_13.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (45)_2.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (45)_2.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (45)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (45)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (45)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (45)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (45)_8.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (45)_8.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (46)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (46)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (47)_15.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (47)_15.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (48)_1.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (48)_1.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (48)_2.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (48)_2.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (49)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (49)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (49)_13.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (49)_13.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (49)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (49)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (5)_12.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (5)_12.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (5)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (5)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (50)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (50)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (50)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (50)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (50)_12.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (50)_12.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (50)_2.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (50)_2.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (50)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (50)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (51)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (51)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (51)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (51)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (51)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (51)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (52)_2.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (52)_2.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (52)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (52)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (53)_13.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (53)_13.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (53)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (53)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (53)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (53)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (54)_15.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (54)_15.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (55)_1.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (55)_1.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (55)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (55)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (55)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (55)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (55)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (55)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (56)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (56)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (56)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (56)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (56)_7.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (56)_7.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (56)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (56)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (57)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (57)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (57)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (57)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (57)_15.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (57)_15.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (58)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (58)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (58)_13.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (58)_13.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (59)_1.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (59)_1.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (59)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (59)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (59)_8.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (59)_8.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (60)_12.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (60)_12.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (60)_13.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (60)_13.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (60)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (60)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (60)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (60)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (60)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (60)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (61)_8.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (61)_8.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (62)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (62)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (65)_12.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (65)_12.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (65)_2.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (65)_2.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (65)_7.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (65)_7.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (65)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (65)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (66)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (66)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (67)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (67)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (67)_12.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (67)_12.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (67)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (67)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (67)_8.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (67)_8.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (67)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (67)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (68)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (68)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (68)_5.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (68)_5.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (68)_7.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (68)_7.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (69)_1.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (69)_1.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (69)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (69)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (70)_1.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (70)_1.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (70)_12.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (70)_12.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (70)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (70)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (70)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (70)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (71)_12.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (71)_12.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (71)_13.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (71)_13.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (71)_2.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (71)_2.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (71)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (71)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (71)_7.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (71)_7.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (72)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (72)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (74)_1.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (74)_1.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (74)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (74)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (74)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (74)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (74)_12.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (74)_12.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (75)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (75)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (75)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (75)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (76)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (76)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (76)_7.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (76)_7.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (78)_13.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (78)_13.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (78)_8.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (78)_8.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (79)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (79)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (79)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (79)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (8)_12.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (8)_12.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (8)_9.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (8)_9.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (80)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (80)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (80)_15.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (80)_15.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (80)_8.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (80)_8.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (81)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (81)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (82)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (82)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (82)_7.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (82)_7.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (83)_15.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (83)_15.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (83)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (83)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (84)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (84)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (84)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (84)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (86)_12.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (86)_12.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (87)_14.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (87)_14.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (88)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (88)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (88)_4.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (88)_4.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (88)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (88)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (88)_7.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (88)_7.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (9)_3.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (9)_3.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (9)_6.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (9)_6.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (9)_7.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (9)_7.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (90)_10.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (90)_10.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (90)_11.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (90)_11.txt -> C:\MTP1\augmented\Dataset\labels\test
# Moved image: poppy (90)_7.jpg -> C:\MTP1\augmented\Dataset\images\test
# Moved text: poppy (90)_7.txt -> C:\MTP1\augmented\Dataset\labels\test
#
# --- Summary ---
# Moved 1583 image file(s).
# Moved 1583 text file(s).
# Skipped 0 item(s).
# File organization complete.
