# %%
# !pip install albumentations
# Out:
# Requirement already satisfied: albumentations in c:\users\krish\appdata\roaming\python\python311\site-packages (2.0.5)
# Requirement already satisfied: numpy>=1.24.4 in c:\users\krish\appdata\roaming\python\python311\site-packages (from albumentations) (2.2.4)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from albumentations) (1.14.1)
# Requirement already satisfied: PyYAML in c:\users\krish\appdata\roaming\python\python311\site-packages (from albumentations) (6.0.2)
# Requirement already satisfied: pydantic>=2.9.2 in c:\users\krish\appdata\roaming\python\python311\site-packages (from albumentations) (2.11.2)
# Requirement already satisfied: albucore==0.0.23 in c:\users\krish\appdata\roaming\python\python311\site-packages (from albumentations) (0.0.23)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in c:\users\krish\appdata\roaming\python\python311\site-packages (from albumentations) (4.11.0.86)
# Requirement already satisfied: stringzilla>=3.10.4 in c:\users\krish\appdata\roaming\python\python311\site-packages (from albucore==0.0.23->albumentations) (3.12.3)
# Requirement already satisfied: simsimd>=5.9.2 in c:\users\krish\appdata\roaming\python\python311\site-packages (from albucore==0.0.23->albumentations) (6.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\krish\appdata\roaming\python\python311\site-packages (from pydantic>=2.9.2->albumentations) (2.33.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\krish\appdata\roaming\python\python311\site-packages (from pydantic>=2.9.2->albumentations) (4.12.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\krish\appdata\roaming\python\python311\site-packages (from pydantic>=2.9.2->albumentations) (0.4.0)
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import albumentations as A
import xml.etree.ElementTree as ET
import os

# Define the augmentation pipeline
transform = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.RandomBrightnessContrast(p=0.5),
    A.RandomBrightnessContrast(brightness_limit=(-0.1, -0.1), contrast_limit=0, p=0.3),  # Low brightness
    A.Blur(blur_limit=5, p=0.1),
    A.Sharpen(alpha=(0.2, 0.5), lightness=(0.5, 1.0), p=0.3),  # controls all color-related params
], bbox_params=A.BboxParams(format='pascal_voc', label_fields=['category_ids'], min_visibility=0.1))

# Parse Pascal VOC XML file
def parse_xml(xml_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()
    bboxes = []
    labels = []

    for obj in root.findall("object"):
        label = obj.find("name").text
        bbox = obj.find("bndbox")
        xmin, ymin, xmax, ymax = map(int, [
            bbox.find("xmin").text, bbox.find("ymin").text,
            bbox.find("xmax").text, bbox.find("ymax").text
        ])
        bboxes.append([xmin, ymin, xmax, ymax])
        labels.append(label)

    return bboxes, labels, tree, root

# Update XML file with new bounding boxes and image size
def update_xml(xml_path, new_bboxes, new_labels, tree, root, new_filename, new_shape):
    root.find("filename").text = new_filename
    root.find("size").find("width").text = str(new_shape[1])
    root.find("size").find("height").text = str(new_shape[0])
    root.find("size").find("depth").text = str(new_shape[2])

    objects = root.findall("object")
    for i, obj in enumerate(objects):
        if i >= len(new_bboxes):  # Avoid index error
            root.remove(obj)
            continue
        bbox = obj.find("bndbox")
        bbox.find("xmin").text = str(int(new_bboxes[i][0]))
        bbox.find("ymin").text = str(int(new_bboxes[i][1]))
        bbox.find("xmax").text = str(int(new_bboxes[i][2]))
        bbox.find("ymax").text = str(int(new_bboxes[i][3]))
        obj.find("name").text = new_labels[i]

    tree.write(xml_path)

# Augment the dataset in a folder
def augment_dataset(input_folder, output_folder, num_aug=15):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    image_files = [f for f in os.listdir(input_folder) if f.endswith(('.jpg', '.png'))]

    for file in image_files:
        image_path = os.path.join(input_folder, file)
        xml_path = os.path.splitext(image_path)[0] + '.xml'

        if not os.path.exists(xml_path):
            print(f"⚠️ XML not found for {file}, skipping.")
            continue

        image = cv2.imread(image_path)
        bboxes, labels, xml_tree, xml_root = parse_xml(xml_path)

        count = 0
        attempts = 0
        while count < num_aug and attempts < num_aug * 3:  # Allow retries in case of bbox loss
            augmented = transform(image=image, bboxes=bboxes, category_ids=labels)
            aug_image = augmented["image"]
            aug_bboxes = augmented["bboxes"]
            aug_labels = augmented["category_ids"]

            # Skip if any bbox is lost
            if len(aug_bboxes) != len(bboxes):
                attempts += 1
                continue

            base_name = os.path.splitext(file)[0]
            new_image_name = f"{base_name}_aug_{count+1}.jpg"
            new_image_path = os.path.join(output_folder, new_image_name)
            new_xml_path = os.path.join(output_folder, f"{base_name}_aug_{count+1}.xml")

            cv2.imwrite(new_image_path, aug_image)
            update_xml(new_xml_path, aug_bboxes, aug_labels, xml_tree, xml_root, new_image_name, aug_image.shape)
            count += 1
            attempts += 1

        print(f"✅ {file}: {count} augmentations saved.")

# === Configure your folders ===
input_folder = r"C:\\MTP1\\augmented\\Original without aug data"      # Folder with original .jpg and .xml files
output_folder = r"C:\\MTP1\\augmented\\aug1"         # Folder to save augmented files

# === Run the augmentation ===
augment_dataset(input_folder, output_folder, num_aug=15)
# Out:
# ✅ duck (1).png: 15 augmentations saved.
# ✅ duck (10).png: 15 augmentations saved.
# ✅ duck (11).png: 15 augmentations saved.
# ✅ duck (12).png: 15 augmentations saved.
# ✅ duck (13).png: 15 augmentations saved.
# ✅ duck (14).png: 15 augmentations saved.
# ✅ duck (16).png: 15 augmentations saved.
# ✅ duck (17).png: 15 augmentations saved.
# ✅ duck (19).png: 15 augmentations saved.
# ✅ duck (2).png: 15 augmentations saved.
# ✅ duck (20).png: 15 augmentations saved.
# ✅ duck (21).png: 15 augmentations saved.
# ✅ duck (22).png: 15 augmentations saved.
# ✅ duck (23).png: 15 augmentations saved.
# ✅ duck (24).png: 15 augmentations saved.
# ✅ duck (25).png: 15 augmentations saved.
# ✅ duck (26).png: 15 augmentations saved.
# ✅ duck (27).png: 15 augmentations saved.
# ✅ duck (28).png: 15 augmentations saved.
# ✅ duck (29).png: 15 augmentations saved.
# ✅ duck (3).png: 15 augmentations saved.
# ✅ duck (30).png: 15 augmentations saved.
# ✅ duck (31).png: 15 augmentations saved.
# ✅ duck (32).png: 15 augmentations saved.
# ✅ duck (33).png: 15 augmentations saved.
# ✅ duck (34).png: 15 augmentations saved.
# ✅ duck (35).png: 15 augmentations saved.
# ✅ duck (36).png: 15 augmentations saved.
# ✅ duck (37).png: 15 augmentations saved.
# ✅ duck (38).png: 15 augmentations saved.
# ✅ duck (39).png: 15 augmentations saved.
# ✅ duck (4).png: 15 augmentations saved.
# ✅ duck (41).png: 15 augmentations saved.
# ✅ duck (42).png: 15 augmentations saved.
# ✅ duck (43).png: 15 augmentations saved.
# ✅ duck (44).png: 15 augmentations saved.
# ✅ duck (45).png: 15 augmentations saved.
# ✅ duck (46).png: 15 augmentations saved.
# ✅ duck (47).png: 15 augmentations saved.
# ✅ duck (48).png: 15 augmentations saved.
# ✅ duck (49).png: 15 augmentations saved.
# ✅ duck (5).png: 15 augmentations saved.
# ✅ duck (50).png: 15 augmentations saved.
# ✅ duck (51).png: 15 augmentations saved.
# ✅ duck (52).png: 15 augmentations saved.
# ✅ duck (53).png: 15 augmentations saved.
# ✅ duck (54).png: 15 augmentations saved.
# ✅ duck (55).png: 15 augmentations saved.
# ✅ duck (56).png: 15 augmentations saved.
# ✅ duck (57).png: 15 augmentations saved.
# ✅ duck (58).png: 15 augmentations saved.
# ✅ duck (59).png: 15 augmentations saved.
# ✅ duck (6).png: 15 augmentations saved.
# ✅ duck (60).png: 15 augmentations saved.
# ✅ duck (61).png: 15 augmentations saved.
# ✅ duck (62).png: 15 augmentations saved.
# ✅ duck (63).png: 15 augmentations saved.
# ✅ duck (64).png: 15 augmentations saved.
# ✅ duck (65).png: 15 augmentations saved.
# ✅ duck (66).png: 15 augmentations saved.
# ✅ duck (67).png: 15 augmentations saved.
# ✅ duck (68).png: 15 augmentations saved.
# ✅ duck (69).png: 15 augmentations saved.
# ✅ duck (7).png: 15 augmentations saved.
# ✅ duck (70).png: 15 augmentations saved.
# ✅ duck (71).png: 15 augmentations saved.
# ✅ duck (72).png: 15 augmentations saved.
# ✅ duck (73).png: 15 augmentations saved.
# ✅ duck (74).png: 15 augmentations saved.
# ✅ duck (77).png: 15 augmentations saved.
# ✅ duck (78).png: 15 augmentations saved.
# ✅ duck (79).png: 15 augmentations saved.
# ✅ duck (8).png: 15 augmentations saved.
# ✅ duck (80).png: 15 augmentations saved.
# ✅ duck (82).png: 15 augmentations saved.
# ✅ duck (83).png: 15 augmentations saved.
# ✅ duck (84).png: 15 augmentations saved.
# ✅ duck (85).png: 15 augmentations saved.
# ✅ duck (86).png: 15 augmentations saved.
# ✅ duck (87).png: 15 augmentations saved.
# ✅ duck (88).png: 15 augmentations saved.
# ✅ duck (89).png: 15 augmentations saved.
# ✅ duck (9).png: 15 augmentations saved.
# ✅ duck (90).png: 15 augmentations saved.
# ✅ duck (92).png: 15 augmentations saved.
# ✅ duck (93).png: 15 augmentations saved.
# ✅ duck (94).png: 15 augmentations saved.
# ✅ duck (96).png: 15 augmentations saved.
# ✅ duck (97).png: 15 augmentations saved.
# ✅ duck (98).png: 15 augmentations saved.
# ✅ duck (99).png: 15 augmentations saved.
# ✅ duck1 (1).jpg: 15 augmentations saved.
# ✅ duck1 (10).jpg: 15 augmentations saved.
# ✅ duck1 (11).jpg: 15 augmentations saved.
# ✅ duck1 (12).jpg: 15 augmentations saved.
# ✅ duck1 (13).jpg: 15 augmentations saved.
# ✅ duck1 (14).jpg: 15 augmentations saved.
# ✅ duck1 (15).jpg: 15 augmentations saved.
# ✅ duck1 (16).jpg: 15 augmentations saved.
# ✅ duck1 (17).jpg: 15 augmentations saved.
# ✅ duck1 (18).jpg: 15 augmentations saved.
# ✅ duck1 (19).jpg: 15 augmentations saved.
# ✅ duck1 (2).jpg: 15 augmentations saved.
# ✅ duck1 (20).jpg: 15 augmentations saved.
# ✅ duck1 (3).jpg: 15 augmentations saved.
# ✅ duck1 (4).jpg: 15 augmentations saved.
# ✅ duck1 (5).jpg: 15 augmentations saved.
# ✅ duck1 (6).jpg: 15 augmentations saved.
# ✅ duck1 (7).jpg: 15 augmentations saved.
# ✅ duck1 (8).jpg: 15 augmentations saved.
# ✅ duck1 (9).jpg: 15 augmentations saved.
# ✅ fish (1).jpg: 15 augmentations saved.
# ✅ fish (10).jpg: 15 augmentations saved.
# ✅ fish (100).jpg: 15 augmentations saved.
# ✅ fish (101).jpg: 15 augmentations saved.
# ✅ fish (102).jpg: 15 augmentations saved.
# ✅ fish (103).jpg: 15 augmentations saved.
# ✅ fish (104).jpg: 15 augmentations saved.
# ✅ fish (105).jpg: 15 augmentations saved.
# ✅ fish (106).jpg: 15 augmentations saved.
# ✅ fish (107).jpg: 15 augmentations saved.
# ✅ fish (108).jpg: 15 augmentations saved.
# ✅ fish (109).jpg: 15 augmentations saved.
# ✅ fish (11).jpg: 15 augmentations saved.
# ✅ fish (110).jpg: 15 augmentations saved.
# ✅ fish (111).jpg: 15 augmentations saved.
# ✅ fish (112).jpg: 15 augmentations saved.
# ✅ fish (113).jpg: 15 augmentations saved.
# ✅ fish (114).jpg: 15 augmentations saved.
# ✅ fish (115).jpg: 15 augmentations saved.
# ✅ fish (116).jpg: 15 augmentations saved.
# ✅ fish (117).jpg: 15 augmentations saved.
# ✅ fish (118).jpg: 15 augmentations saved.
# ✅ fish (119).jpg: 15 augmentations saved.
# ✅ fish (12).jpg: 15 augmentations saved.
# ✅ fish (120).jpg: 15 augmentations saved.
# ✅ fish (121).jpg: 15 augmentations saved.
# ✅ fish (122).jpg: 15 augmentations saved.
# ✅ fish (123).jpg: 15 augmentations saved.
# ✅ fish (124).jpg: 15 augmentations saved.
# ✅ fish (125).jpg: 15 augmentations saved.
# ✅ fish (126).jpg: 15 augmentations saved.
# ✅ fish (127).jpg: 15 augmentations saved.
# ✅ fish (128).jpg: 15 augmentations saved.
# ✅ fish (129).jpg: 15 augmentations saved.
# ✅ fish (13).jpg: 15 augmentations saved.
# ✅ fish (130).jpg: 15 augmentations saved.
# ✅ fish (131).jpg: 15 augmentations saved.
# ✅ fish (132).jpg: 15 augmentations saved.
# ✅ fish (133).jpg: 15 augmentations saved.
# ✅ fish (134).jpg: 15 augmentations saved.
# ✅ fish (135).jpg: 15 augmentations saved.
# ✅ fish (136).jpg: 15 augmentations saved.
# ✅ fish (137).jpg: 15 augmentations saved.
# ✅ fish (138).jpg: 15 augmentations saved.
# ✅ fish (139).jpg: 15 augmentations saved.
# ✅ fish (14).jpg: 15 augmentations saved.
# ✅ fish (140).jpg: 15 augmentations saved.
# ✅ fish (141).jpg: 15 augmentations saved.
# ✅ fish (142).jpg: 15 augmentations saved.
# ✅ fish (143).jpg: 15 augmentations saved.
# ✅ fish (144).jpg: 15 augmentations saved.
# ✅ fish (145).jpg: 15 augmentations saved.
# ✅ fish (146).jpg: 15 augmentations saved.
# ✅ fish (147).jpg: 15 augmentations saved.
# ✅ fish (148).jpg: 15 augmentations saved.
# ✅ fish (149).jpg: 15 augmentations saved.
# ✅ fish (15).jpg: 15 augmentations saved.
# ✅ fish (150).jpg: 15 augmentations saved.
# ✅ fish (151).jpg: 15 augmentations saved.
# ✅ fish (152).jpg: 15 augmentations saved.
# ✅ fish (153).jpg: 15 augmentations saved.
# ✅ fish (154).jpg: 15 augmentations saved.
# ✅ fish (155).jpg: 15 augmentations saved.
# ✅ fish (156).jpg: 15 augmentations saved.
# ✅ fish (157).jpg: 15 augmentations saved.
# ✅ fish (158).jpg: 15 augmentations saved.
# ✅ fish (159).jpg: 15 augmentations saved.
# ✅ fish (16).jpg: 15 augmentations saved.
# ✅ fish (160).jpg: 15 augmentations saved.
# ✅ fish (17).jpg: 15 augmentations saved.
# ✅ fish (18).jpg: 15 augmentations saved.
# ✅ fish (19).jpg: 15 augmentations saved.
# ✅ fish (2).jpg: 15 augmentations saved.
# ✅ fish (20).jpg: 15 augmentations saved.
# ✅ fish (21).jpg: 15 augmentations saved.
# ✅ fish (22).jpg: 15 augmentations saved.
# ✅ fish (23).jpg: 15 augmentations saved.
# ✅ fish (24).jpg: 15 augmentations saved.
# ✅ fish (25).jpg: 15 augmentations saved.
# ✅ fish (26).jpg: 15 augmentations saved.
# ✅ fish (27).jpg: 15 augmentations saved.
# ✅ fish (28).jpg: 15 augmentations saved.
# ✅ fish (29).jpg: 15 augmentations saved.
# ✅ fish (3).jpg: 15 augmentations saved.
# ✅ fish (30).jpg: 15 augmentations saved.
# ✅ fish (31).jpg: 15 augmentations saved.
# ✅ fish (32).jpg: 15 augmentations saved.
# ✅ fish (33).jpg: 15 augmentations saved.
# ✅ fish (34).jpg: 15 augmentations saved.
# ✅ fish (35).jpg: 15 augmentations saved.
# ✅ fish (36).jpg: 15 augmentations saved.
# ✅ fish (37).jpg: 15 augmentations saved.
# ✅ fish (38).jpg: 15 augmentations saved.
# ✅ fish (39).jpg: 15 augmentations saved.
# ✅ fish (4).jpg: 15 augmentations saved.
# ✅ fish (40).jpg: 15 augmentations saved.
# ✅ fish (41).jpg: 15 augmentations saved.
# ✅ fish (42).jpg: 15 augmentations saved.
# ✅ fish (43).jpg: 15 augmentations saved.
# ✅ fish (44).jpg: 15 augmentations saved.
# ✅ fish (45).jpg: 15 augmentations saved.
# ✅ fish (46).jpg: 15 augmentations saved.
# ✅ fish (47).jpg: 15 augmentations saved.
# ✅ fish (48).jpg: 15 augmentations saved.
# ✅ fish (49).jpg: 15 augmentations saved.
# ✅ fish (5).jpg: 15 augmentations saved.
# ✅ fish (50).jpg: 15 augmentations saved.
# ✅ fish (51).jpg: 15 augmentations saved.
# ✅ fish (52).jpg: 15 augmentations saved.
# ✅ fish (53).jpg: 15 augmentations saved.
# ✅ fish (54).jpg: 15 augmentations saved.
# ✅ fish (55).jpg: 15 augmentations saved.
# ✅ fish (56).jpg: 15 augmentations saved.
# ✅ fish (57).jpg: 15 augmentations saved.
# ✅ fish (58).jpg: 15 augmentations saved.
# ✅ fish (59).jpg: 15 augmentations saved.
# ✅ fish (6).jpg: 15 augmentations saved.
# ✅ fish (60).jpg: 15 augmentations saved.
# ✅ fish (61).jpg: 15 augmentations saved.
# ✅ fish (62).jpg: 15 augmentations saved.
# ✅ fish (63).jpg: 15 augmentations saved.
# ✅ fish (64).jpg: 15 augmentations saved.
# ✅ fish (65).jpg: 15 augmentations saved.
# ✅ fish (66).jpg: 15 augmentations saved.
# ✅ fish (67).jpg: 15 augmentations saved.
# ✅ fish (68).jpg: 15 augmentations saved.
# ✅ fish (69).jpg: 15 augmentations saved.
# ✅ fish (7).jpg: 15 augmentations saved.
# ✅ fish (70).jpg: 15 augmentations saved.
# ✅ fish (71).jpg: 15 augmentations saved.
# ✅ fish (72).jpg: 15 augmentations saved.
# ✅ fish (73).jpg: 15 augmentations saved.
# ✅ fish (74).jpg: 15 augmentations saved.
# ✅ fish (75).jpg: 15 augmentations saved.
# ✅ fish (76).jpg: 15 augmentations saved.
# ✅ fish (77).jpg: 15 augmentations saved.
# ✅ fish (78).jpg: 15 augmentations saved.
# ✅ fish (79).jpg: 15 augmentations saved.
# ✅ fish (8).jpg: 15 augmentations saved.
# ✅ fish (80).jpg: 15 augmentations saved.
# ✅ fish (81).jpg: 15 augmentations saved.
# ✅ fish (82).jpg: 15 augmentations saved.
# ✅ fish (83).jpg: 15 augmentations saved.
# ✅ fish (84).jpg: 15 augmentations saved.
# ✅ fish (85).jpg: 15 augmentations saved.
# ✅ fish (89).jpg: 15 augmentations saved.
# ✅ fish (9).jpg: 15 augmentations saved.
# ✅ fish (90).jpg: 15 augmentations saved.
# ✅ fish (91).jpg: 15 augmentations saved.
# ✅ fish (92).jpg: 15 augmentations saved.
# ✅ fish (93).jpg: 15 augmentations saved.
# ✅ fish (94).jpg: 15 augmentations saved.
# ✅ fish (95).jpg: 15 augmentations saved.
# ✅ fish (96).jpg: 15 augmentations saved.
# ✅ fish (97).jpg: 15 augmentations saved.
# ✅ fish (98).jpg: 15 augmentations saved.
# ✅ fish (99).jpg: 15 augmentations saved.
# ✅ FLower (1).png: 15 augmentations saved.
# ✅ FLower (10).png: 15 augmentations saved.
# ✅ FLower (100).png: 15 augmentations saved.
# ✅ FLower (101).png: 15 augmentations saved.
# ✅ FLower (102).png: 15 augmentations saved.
# ✅ FLower (103).png: 15 augmentations saved.
# ✅ FLower (105).png: 15 augmentations saved.
# ✅ FLower (106).png: 15 augmentations saved.
# ✅ FLower (107).png: 15 augmentations saved.
# ✅ FLower (108).png: 15 augmentations saved.
# ✅ FLower (109).png: 15 augmentations saved.
# ✅ FLower (11).png: 15 augmentations saved.
# ✅ FLower (110).png: 15 augmentations saved.
# ✅ FLower (112).png: 15 augmentations saved.
# ✅ FLower (113).png: 15 augmentations saved.
# ✅ FLower (114).png: 15 augmentations saved.
# ✅ FLower (116).png: 15 augmentations saved.
# ✅ FLower (117).png: 15 augmentations saved.
# ✅ FLower (118).png: 15 augmentations saved.
# ✅ FLower (12).png: 15 augmentations saved.
# ✅ FLower (120).png: 15 augmentations saved.
# ✅ FLower (121).png: 15 augmentations saved.
# ✅ FLower (122).png: 15 augmentations saved.
# ✅ FLower (123).png: 15 augmentations saved.
# ✅ FLower (125).png: 15 augmentations saved.
# ✅ FLower (126).png: 15 augmentations saved.
# ✅ FLower (127).png: 15 augmentations saved.
# ✅ FLower (128).png: 15 augmentations saved.
# ✅ FLower (13).png: 15 augmentations saved.
# ✅ FLower (130).png: 15 augmentations saved.
# ✅ FLower (131).png: 15 augmentations saved.
# ✅ FLower (133).png: 15 augmentations saved.
# ✅ FLower (134).png: 15 augmentations saved.
# ✅ FLower (135).png: 15 augmentations saved.
# ✅ FLower (136).png: 15 augmentations saved.
# ✅ FLower (137).png: 15 augmentations saved.
# ✅ FLower (138).png: 15 augmentations saved.
# ✅ FLower (139).png: 15 augmentations saved.
# ✅ FLower (14).png: 15 augmentations saved.
# ✅ FLower (140).png: 15 augmentations saved.
# ✅ FLower (141).png: 15 augmentations saved.
# ✅ FLower (143).png: 15 augmentations saved.
# ✅ FLower (144).png: 15 augmentations saved.
# ✅ FLower (145).png: 15 augmentations saved.
# ✅ FLower (146).png: 15 augmentations saved.
# ✅ FLower (147).png: 15 augmentations saved.
# ✅ FLower (148).png: 15 augmentations saved.
# ✅ FLower (149).png: 15 augmentations saved.
# ✅ FLower (15).png: 15 augmentations saved.
# ✅ FLower (157).png: 15 augmentations saved.
# ✅ FLower (158).png: 15 augmentations saved.
# ✅ FLower (16).png: 15 augmentations saved.
# ✅ FLower (161).png: 15 augmentations saved.
# ✅ FLower (162).png: 15 augmentations saved.
# ✅ FLower (163).png: 15 augmentations saved.
# ✅ FLower (165).png: 15 augmentations saved.
# ✅ FLower (168).png: 15 augmentations saved.
# ✅ FLower (17).png: 15 augmentations saved.
# ✅ FLower (170).png: 15 augmentations saved.
# ✅ FLower (173).png: 15 augmentations saved.
# ✅ FLower (174).png: 15 augmentations saved.
# ✅ FLower (176).png: 15 augmentations saved.
# ✅ FLower (178).png: 15 augmentations saved.
# ✅ FLower (179).png: 15 augmentations saved.
# ✅ FLower (18).png: 15 augmentations saved.
# ✅ FLower (180).png: 15 augmentations saved.
# ✅ FLower (181).png: 15 augmentations saved.
# ✅ FLower (182).png: 15 augmentations saved.
# ✅ FLower (186).png: 15 augmentations saved.
# ✅ FLower (188).png: 15 augmentations saved.
# ✅ FLower (19).png: 15 augmentations saved.
# ✅ FLower (190).png: 15 augmentations saved.
# ✅ FLower (192).png: 15 augmentations saved.
# ✅ FLower (193).png: 15 augmentations saved.
# ✅ FLower (195).png: 15 augmentations saved.
# ✅ FLower (198).png: 15 augmentations saved.
# ✅ FLower (20).png: 15 augmentations saved.
# ✅ FLower (200).png: 15 augmentations saved.
# ✅ FLower (21).png: 15 augmentations saved.
# ✅ FLower (22).png: 15 augmentations saved.
# ✅ FLower (23).png: 15 augmentations saved.
# ✅ FLower (24).png: 15 augmentations saved.
# ✅ FLower (25).png: 15 augmentations saved.
# ✅ FLower (29).png: 15 augmentations saved.
# ✅ FLower (3).png: 15 augmentations saved.
# ✅ FLower (30).png: 15 augmentations saved.
# ✅ FLower (31).png: 15 augmentations saved.
# ✅ FLower (32).png: 15 augmentations saved.
# ✅ FLower (33).png: 15 augmentations saved.
# ✅ FLower (34).png: 15 augmentations saved.
# ✅ FLower (35).png: 15 augmentations saved.
# ✅ FLower (36).png: 15 augmentations saved.
# ✅ FLower (37).png: 15 augmentations saved.
# ✅ FLower (38).png: 15 augmentations saved.
# ✅ FLower (39).png: 15 augmentations saved.
# ✅ FLower (4).png: 15 augmentations saved.
# ✅ FLower (40).png: 15 augmentations saved.
# ✅ FLower (41).png: 15 augmentations saved.
# ✅ FLower (42).png: 15 augmentations saved.
# ✅ FLower (43).png: 15 augmentations saved.
# ✅ FLower (44).png: 15 augmentations saved.
# ✅ FLower (45).png: 15 augmentations saved.
# ✅ FLower (46).png: 15 augmentations saved.
# ✅ FLower (47).png: 15 augmentations saved.
# ✅ FLower (48).png: 15 augmentations saved.
# ✅ FLower (49).png: 15 augmentations saved.
# ✅ FLower (5).png: 15 augmentations saved.
# ✅ FLower (50).png: 15 augmentations saved.
# ✅ FLower (51).png: 15 augmentations saved.
# ✅ FLower (52).png: 15 augmentations saved.
# ✅ FLower (53).png: 15 augmentations saved.
# ✅ FLower (54).png: 15 augmentations saved.
# ✅ FLower (56).png: 15 augmentations saved.
# ✅ FLower (57).png: 15 augmentations saved.
# ✅ FLower (58).png: 15 augmentations saved.
# ✅ FLower (59).png: 15 augmentations saved.
# ✅ FLower (6).png: 15 augmentations saved.
# ✅ FLower (60).png: 15 augmentations saved.
# ✅ FLower (61).png: 15 augmentations saved.
# ✅ FLower (62).png: 15 augmentations saved.
# ✅ FLower (63).png: 15 augmentations saved.
# ✅ FLower (64).png: 15 augmentations saved.
# ✅ FLower (65).png: 15 augmentations saved.
# ✅ FLower (66).png: 15 augmentations saved.
# ✅ FLower (67).png: 15 augmentations saved.
# ✅ FLower (68).png: 15 augmentations saved.
# ✅ FLower (69).png: 15 augmentations saved.
# ✅ FLower (70).png: 15 augmentations saved.
# ✅ FLower (71).png: 15 augmentations saved.
# ✅ FLower (72).png: 15 augmentations saved.
# ✅ FLower (73).png: 15 augmentations saved.
# ✅ FLower (74).png: 15 augmentations saved.
# ✅ FLower (75).png: 15 augmentations saved.
# ✅ FLower (76).png: 15 augmentations saved.
# ✅ FLower (77).png: 15 augmentations saved.
# ✅ FLower (78).png: 15 augmentations saved.
# ✅ FLower (8).png: 15 augmentations saved.
# ✅ FLower (80).png: 15 augmentations saved.
# ✅ FLower (81).png: 15 augmentations saved.
# ✅ FLower (82).png: 15 augmentations saved.
# ✅ FLower (83).png: 15 augmentations saved.
# ✅ FLower (85).png: 15 augmentations saved.
# ✅ FLower (86).png: 15 augmentations saved.
# ✅ FLower (87).png: 15 augmentations saved.
# ✅ FLower (88).png: 15 augmentations saved.
# ✅ FLower (89).png: 15 augmentations saved.
# ✅ FLower (9).png: 15 augmentations saved.
# ✅ FLower (90).png: 15 augmentations saved.
# ✅ FLower (91).png: 15 augmentations saved.
# ✅ FLower (92).png: 15 augmentations saved.
# ✅ FLower (93).png: 15 augmentations saved.
# ✅ FLower (94).png: 15 augmentations saved.
# ✅ FLower (95).png: 15 augmentations saved.
# ✅ FLower (97).png: 15 augmentations saved.
# ✅ FLower (98).png: 15 augmentations saved.
# ✅ FLower (99).png: 15 augmentations saved.
# ✅ hy (1).png: 15 augmentations saved.
# ✅ hy (10).png: 15 augmentations saved.
# ✅ hy (100).png: 15 augmentations saved.
# ✅ hy (102).png: 15 augmentations saved.
# ✅ hy (11).png: 15 augmentations saved.
# ✅ hy (12).png: 15 augmentations saved.
# ✅ hy (14).png: 15 augmentations saved.
# ✅ hy (15).png: 15 augmentations saved.
# ✅ hy (16).png: 15 augmentations saved.
# ✅ hy (17).png: 15 augmentations saved.
# ✅ hy (18).png: 15 augmentations saved.
# ✅ hy (19).png: 15 augmentations saved.
# ✅ hy (2).png: 15 augmentations saved.
# ✅ hy (20).png: 15 augmentations saved.
# ✅ hy (21).png: 15 augmentations saved.
# ✅ hy (22).png: 15 augmentations saved.
# ✅ hy (23).png: 15 augmentations saved.
# ✅ hy (25).png: 15 augmentations saved.
# ✅ hy (26).png: 15 augmentations saved.
# ✅ hy (28).png: 15 augmentations saved.
# ✅ hy (29).png: 15 augmentations saved.
# ✅ hy (3).png: 15 augmentations saved.
# ✅ hy (30).png: 15 augmentations saved.
# ✅ hy (31).png: 15 augmentations saved.
# ✅ hy (32).png: 15 augmentations saved.
# ✅ hy (33).png: 15 augmentations saved.
# ✅ hy (34).png: 15 augmentations saved.
# ✅ hy (35).png: 15 augmentations saved.
# ✅ hy (36).png: 15 augmentations saved.
# ✅ hy (37).png: 15 augmentations saved.
# ✅ hy (38).png: 15 augmentations saved.
# ✅ hy (39).png: 15 augmentations saved.
# ✅ hy (4).png: 15 augmentations saved.
# ✅ hy (40).png: 15 augmentations saved.
# ✅ hy (41).png: 15 augmentations saved.
# ✅ hy (42).png: 15 augmentations saved.
# ✅ hy (43).png: 15 augmentations saved.
# ✅ hy (44).png: 15 augmentations saved.
# ✅ hy (45).png: 15 augmentations saved.
# ✅ hy (46).png: 15 augmentations saved.
# ✅ hy (47).png: 15 augmentations saved.
# ✅ hy (48).png: 15 augmentations saved.
# ✅ hy (49).png: 15 augmentations saved.
# ✅ hy (5).png: 15 augmentations saved.
# ✅ hy (50).png: 15 augmentations saved.
# ✅ hy (51).png: 15 augmentations saved.
# ✅ hy (52).png: 15 augmentations saved.
# ✅ hy (53).png: 15 augmentations saved.
# ✅ hy (54).png: 15 augmentations saved.
# ✅ hy (55).png: 15 augmentations saved.
# ✅ hy (56).png: 15 augmentations saved.
# ✅ hy (57).png: 15 augmentations saved.
# ✅ hy (58).png: 15 augmentations saved.
# ✅ hy (59).png: 15 augmentations saved.
# ✅ hy (6).png: 15 augmentations saved.
# ✅ hy (60).png: 15 augmentations saved.
# ✅ hy (61).png: 15 augmentations saved.
# ✅ hy (62).png: 15 augmentations saved.
# ✅ hy (63).png: 15 augmentations saved.
# ✅ hy (64).png: 15 augmentations saved.
# ✅ hy (65).png: 15 augmentations saved.
# ✅ hy (66).png: 15 augmentations saved.
# ✅ hy (67).png: 15 augmentations saved.
# ✅ hy (68).png: 15 augmentations saved.
# ✅ hy (7).png: 15 augmentations saved.
# ✅ hy (70).png: 15 augmentations saved.
# ✅ hy (71).png: 15 augmentations saved.
# ✅ hy (73).png: 15 augmentations saved.
# ✅ hy (74).png: 15 augmentations saved.
# ✅ hy (75).png: 15 augmentations saved.
# ✅ hy (76).png: 15 augmentations saved.
# ✅ hy (77).png: 15 augmentations saved.
# ✅ hy (78).png: 15 augmentations saved.
# ✅ hy (79).png: 15 augmentations saved.
# ✅ hy (8).png: 15 augmentations saved.
# ✅ hy (80).png: 15 augmentations saved.
# ✅ hy (81).png: 15 augmentations saved.
# ✅ hy (82).png: 15 augmentations saved.
# ✅ hy (83).png: 15 augmentations saved.
# ✅ hy (84).png: 15 augmentations saved.
# ✅ hy (85).png: 15 augmentations saved.
# ✅ hy (86).png: 15 augmentations saved.
# ✅ hy (87).png: 15 augmentations saved.
# ✅ hy (9).png: 15 augmentations saved.
# ✅ hy (90).png: 15 augmentations saved.
# ✅ hy (91).png: 15 augmentations saved.
# ✅ hy (92).png: 15 augmentations saved.
# ✅ hy (93).png: 15 augmentations saved.
# ✅ hy (94).png: 15 augmentations saved.
# ✅ hy (95).png: 15 augmentations saved.
# ✅ hy (96).png: 15 augmentations saved.
# ✅ hy (97).png: 15 augmentations saved.
# ✅ hy (98).png: 15 augmentations saved.
# ✅ hy (99).png: 15 augmentations saved.
# ✅ image (1).png: 15 augmentations saved.
# ✅ image (10).png: 15 augmentations saved.
# ✅ image (100).png: 15 augmentations saved.
# ✅ image (11).png: 15 augmentations saved.
# ✅ image (12).png: 15 augmentations saved.
# ✅ image (13).png: 15 augmentations saved.
# ✅ image (14).png: 15 augmentations saved.
# ✅ image (15).png: 15 augmentations saved.
# ✅ image (16).png: 15 augmentations saved.
# ✅ image (17).png: 15 augmentations saved.
# ✅ image (18).png: 15 augmentations saved.
# ✅ image (19).png: 15 augmentations saved.
# ✅ image (2).png: 15 augmentations saved.
# ✅ image (20).png: 15 augmentations saved.
# ✅ image (21).png: 15 augmentations saved.
# ✅ image (22).png: 15 augmentations saved.
# ✅ image (23).png: 15 augmentations saved.
# ✅ image (24).png: 15 augmentations saved.
# ✅ image (25).png: 15 augmentations saved.
# ✅ image (26).png: 15 augmentations saved.
# ✅ image (27).png: 15 augmentations saved.
# ✅ image (28).png: 15 augmentations saved.
# ✅ image (29).png: 15 augmentations saved.
# ✅ image (3).png: 15 augmentations saved.
# ✅ image (30).png: 15 augmentations saved.
# ✅ image (31).png: 15 augmentations saved.
# ✅ image (32).png: 15 augmentations saved.
# ✅ image (33).png: 15 augmentations saved.
# ✅ image (34).png: 15 augmentations saved.
# ✅ image (35).png: 15 augmentations saved.
# ✅ image (36).png: 15 augmentations saved.
# ✅ image (37).png: 15 augmentations saved.
# ✅ image (38).png: 15 augmentations saved.
# ✅ image (39).png: 15 augmentations saved.
# ✅ image (4).png: 15 augmentations saved.
# ✅ image (40).png: 15 augmentations saved.
# ✅ image (41).png: 15 augmentations saved.
# ✅ image (42).png: 15 augmentations saved.
# ✅ image (43).png: 15 augmentations saved.
# ✅ image (44).png: 15 augmentations saved.
# ✅ image (45).png: 15 augmentations saved.
# ✅ image (46).png: 15 augmentations saved.
# ✅ image (47).png: 15 augmentations saved.
# ✅ image (48).png: 15 augmentations saved.
# ✅ image (49).png: 15 augmentations saved.
# ✅ image (5).png: 15 augmentations saved.
# ✅ image (50).png: 15 augmentations saved.
# ✅ image (51).png: 15 augmentations saved.
# ✅ image (52).png: 15 augmentations saved.
# ✅ image (53).png: 15 augmentations saved.
# ✅ image (54).png: 15 augmentations saved.
# ✅ image (55).png: 15 augmentations saved.
# ✅ image (56).png: 15 augmentations saved.
# ✅ image (57).png: 15 augmentations saved.
# ✅ image (58).png: 15 augmentations saved.
# ✅ image (59).png: 15 augmentations saved.
# ✅ image (6).png: 15 augmentations saved.
# ✅ image (60).png: 15 augmentations saved.
# ✅ image (61).png: 15 augmentations saved.
# ✅ image (62).png: 15 augmentations saved.
# ✅ image (63).png: 15 augmentations saved.
# ✅ image (64).png: 15 augmentations saved.
# ✅ image (65).png: 15 augmentations saved.
# ✅ image (66).png: 15 augmentations saved.
# ✅ image (67).png: 15 augmentations saved.
# ✅ image (68).png: 15 augmentations saved.
# ✅ image (69).png: 15 augmentations saved.
# ✅ image (7).png: 15 augmentations saved.
# ✅ image (70).png: 15 augmentations saved.
# ✅ image (71).png: 15 augmentations saved.
# ✅ image (72).png: 15 augmentations saved.
# ✅ image (73).png: 15 augmentations saved.
# ✅ image (74).png: 15 augmentations saved.
# ✅ image (75).png: 15 augmentations saved.
# ✅ image (76).png: 15 augmentations saved.
# ✅ image (77).png: 15 augmentations saved.
# ✅ image (78).png: 15 augmentations saved.
# ✅ image (79).png: 15 augmentations saved.
# ✅ image (8).png: 15 augmentations saved.
# ✅ image (80).png: 15 augmentations saved.
# ✅ image (81).png: 15 augmentations saved.
# ✅ image (82).png: 15 augmentations saved.
# ✅ image (83).png: 15 augmentations saved.
# ✅ image (84).png: 15 augmentations saved.
# ✅ image (85).png: 15 augmentations saved.
# ✅ image (86).png: 15 augmentations saved.
# ✅ image (87).png: 15 augmentations saved.
# ✅ image (88).png: 15 augmentations saved.
# ✅ image (89).png: 15 augmentations saved.
# ✅ image (9).png: 15 augmentations saved.
# ✅ image (90).png: 15 augmentations saved.
# ✅ image (91).png: 15 augmentations saved.
# ✅ image (92).png: 15 augmentations saved.
# ✅ image (93).png: 15 augmentations saved.
# ✅ image (94).png: 15 augmentations saved.
# ✅ image (95).png: 15 augmentations saved.
# ✅ image (96).png: 15 augmentations saved.
# ✅ image (97).png: 15 augmentations saved.
# ✅ image (98).png: 15 augmentations saved.
# ✅ image (99).png: 15 augmentations saved.
# ✅ poppy (1).png: 15 augmentations saved.
# ✅ poppy (10).png: 15 augmentations saved.
# ✅ poppy (11).png: 15 augmentations saved.
# ✅ poppy (12).png: 15 augmentations saved.
# ✅ poppy (13).png: 15 augmentations saved.
# ✅ poppy (14).png: 15 augmentations saved.
# ✅ poppy (15).png: 15 augmentations saved.
# ✅ poppy (16).png: 15 augmentations saved.
# ✅ poppy (17).png: 15 augmentations saved.
# ✅ poppy (18).png: 15 augmentations saved.
# ✅ poppy (19).png: 15 augmentations saved.
# ✅ poppy (2).png: 15 augmentations saved.
# ✅ poppy (20).png: 15 augmentations saved.
# ✅ poppy (21).png: 15 augmentations saved.
# ✅ poppy (22).png: 15 augmentations saved.
# ✅ poppy (23).png: 15 augmentations saved.
# ✅ poppy (25).png: 15 augmentations saved.
# ✅ poppy (26).png: 15 augmentations saved.
# ✅ poppy (27).png: 15 augmentations saved.
# ✅ poppy (29).png: 15 augmentations saved.
# ✅ poppy (3).png: 15 augmentations saved.
# ✅ poppy (30).png: 15 augmentations saved.
# ✅ poppy (32).png: 15 augmentations saved.
# ✅ poppy (33).png: 15 augmentations saved.
# ✅ poppy (34).png: 15 augmentations saved.
# ✅ poppy (35).png: 15 augmentations saved.
# ✅ poppy (36).png: 15 augmentations saved.
# ✅ poppy (37).png: 15 augmentations saved.
# ✅ poppy (38).png: 15 augmentations saved.
# ✅ poppy (39).png: 15 augmentations saved.
# ✅ poppy (4).png: 15 augmentations saved.
# ✅ poppy (40).png: 15 augmentations saved.
# ✅ poppy (41).png: 15 augmentations saved.
# ✅ poppy (42).png: 15 augmentations saved.
# ✅ poppy (43).png: 15 augmentations saved.
# ✅ poppy (44).png: 15 augmentations saved.
# ✅ poppy (45).png: 15 augmentations saved.
# ✅ poppy (46).png: 15 augmentations saved.
# ✅ poppy (47).png: 15 augmentations saved.
# ✅ poppy (48).png: 15 augmentations saved.
# ✅ poppy (49).png: 15 augmentations saved.
# ✅ poppy (5).png: 15 augmentations saved.
# ✅ poppy (50).png: 15 augmentations saved.
# ✅ poppy (51).png: 15 augmentations saved.
# ✅ poppy (52).png: 15 augmentations saved.
# ✅ poppy (53).png: 15 augmentations saved.
# ✅ poppy (54).png: 15 augmentations saved.
# ✅ poppy (55).png: 15 augmentations saved.
# ✅ poppy (56).png: 15 augmentations saved.
# ✅ poppy (57).png: 15 augmentations saved.
# ✅ poppy (58).png: 15 augmentations saved.
# ✅ poppy (59).png: 15 augmentations saved.
# ✅ poppy (6).png: 15 augmentations saved.
# ✅ poppy (60).png: 15 augmentations saved.
# ✅ poppy (61).png: 15 augmentations saved.
# ✅ poppy (62).png: 15 augmentations saved.
# ✅ poppy (63).png: 15 augmentations saved.
# ✅ poppy (64).png: 15 augmentations saved.
# ✅ poppy (65).png: 15 augmentations saved.
# ✅ poppy (66).png: 15 augmentations saved.
# ✅ poppy (67).png: 15 augmentations saved.
# ✅ poppy (68).png: 15 augmentations saved.
# ✅ poppy (69).png: 15 augmentations saved.
# ✅ poppy (7).png: 15 augmentations saved.
# ✅ poppy (70).png: 15 augmentations saved.
# ✅ poppy (71).png: 15 augmentations saved.
# ✅ poppy (72).png: 15 augmentations saved.
# ✅ poppy (73).png: 15 augmentations saved.
# ✅ poppy (74).png: 15 augmentations saved.
# ✅ poppy (75).png: 15 augmentations saved.
# ✅ poppy (76).png: 15 augmentations saved.
# ✅ poppy (78).png: 15 augmentations saved.
# ✅ poppy (79).png: 15 augmentations saved.
# ✅ poppy (8).png: 15 augmentations saved.
# ✅ poppy (80).png: 15 augmentations saved.
# ✅ poppy (81).png: 15 augmentations saved.
# ✅ poppy (82).png: 15 augmentations saved.
# ✅ poppy (83).png: 15 augmentations saved.
# ✅ poppy (84).png: 15 augmentations saved.
# ✅ poppy (86).png: 15 augmentations saved.
# ✅ poppy (87).png: 15 augmentations saved.
# ✅ poppy (88).png: 15 augmentations saved.
# ✅ poppy (89).png: 15 augmentations saved.
# ✅ poppy (9).png: 15 augmentations saved.
# ✅ poppy (90).png: 15 augmentations saved.
