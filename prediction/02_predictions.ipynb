# %%
import cv2
from yolo_predictions import YOLO_Pred

# %%
yolo = YOLO_Pred('C:\\MTP1\\prediction\\Model\\weights\\best.onnx', 'C:\\MTP1\\prediction\\data.yaml')

# %%
# img = cv2.imread('duck (1).png')

# # cv2.imshow('img',img)
# # cv2.waitKey(0)
# # cv2.destroyAllWindows()

# # predictions
# img_pred = yolo.predictions(img)

# cv2.imshow('prediction image',img_pred)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('duck (1).png')

# Make prediction
img_pred = yolo.predictions(img)

# Convert BGR → RGB for correct colors
img_pred_rgb = cv2.cvtColor(img_pred, cv2.COLOR_BGR2RGB)

plt.imshow(img_pred_rgb)
plt.axis('off')
plt.title('Prediction Image')
plt.show()

# %%
# img = cv2.imread('duck (1).png')
# if img is None:
#     print("Error: Image not loaded. Check file path.")
# else:
#     # Proceed with predictions
#     img_pred = yolo.predictions(img)
#     cv2.imshow('prediction image', img_pred)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()

# %%
import os
print(os.getcwd())
# Out:
# c:\MTP1\prediction

# %%
# predictions
# img_pred = yolo.predictions(img)

# %%
# cv2.imshow('prediction image',img_pred)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %% [markdown]
# ## Real Time Object Detection

# %%
cap = cv2.VideoCapture('video.mp4')


while True:
    ret, frame = cap.read()
    if ret == False:
        print('unable to read video')
        break
        
    pred_image = yolo.predictions(frame)
    
    cv2.imshow('YOLO',pred_image)
    if cv2.waitKey(1) == 27:
        break
        
cv2.destroyAllWindows()
cap.release()

# %%
import cv2
import matplotlib.pyplot as plt
from IPython.display import clear_output, display
import time

cap = cv2.VideoCapture('test.mp4')

while True:
    ret, frame = cap.read()
    if not ret:
        print('Unable to read video or end of video.')
        break

    pred_image = yolo.predictions(frame)
    pred_rgb = cv2.cvtColor(pred_image, cv2.COLOR_BGR2RGB)

    plt.imshow(pred_rgb)
    plt.axis('off')
    display(plt.gcf())
    clear_output(wait=True)
    time.sleep(0.03)  # ~30 FPS

cap.release()
